# %% [markdown]
# <a href="https://colab.research.google.com/github/salerno-professor/analytics-projeto/blob/main/index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Dados Pessoais
#
# **Nome:** André Salerno
# **Email:** [andresalerno@example.com](mailto:andresalerno@example.com)
# **LinkedIn:** [linkedin.com/in/andresalerno](https://www.linkedin.com/in/andresalerno)
# **Instagram:** [Clique aqui!](https://www.instagram.com/andresalerno)
#
# ---
#
# # 2. Objetivo
#
# Meu objetivo profissional é aplicar minhas habilidades e conhecimentos em **Análise de Dados** para ajudar empresas a tomarem decisões baseadas em dados. Busco sempre me aprimorar em técnicas de **machine learning**, **análise preditiva** e **visualização de dados**, utilizando ferramentas como **Python**, **Pandas**, **Scikit-learn**, e **Power BI**.
#
# ---
#
# # 3. Habilidades (Hard e Soft Skills)
#
# ## 3.1 **Hard Skills**
# - **Análise de Dados**: Experiência prática com ferramentas como **Pandas**, **NumPy**, e **Matplotlib** para análise e visualização de dados.
# - **Modelagem Preditiva**: Conhecimento de técnicas de **regressão**, **classificação** e **agrupamento** (machine learning) com **Scikit-learn**.
# - **SQL**: Habilidade para extrair, manipular e analisar dados em bancos de dados relacionais.
# - **Power BI**: Criação de dashboards interativos e relatórios analíticos para insights de negócios.
# - **Python**: Proficiência em programação para análise de dados e automação de tarefas.
#
# ## 3.2 **Soft Skills**
# - **Comunicação**: Capacidade de explicar conceitos complexos de maneira clara e acessível, tanto para públicos técnicos quanto não técnicos.
# - **Trabalho em Equipe**: Colaboração com equipes multidisciplinares para alcançar objetivos comuns.
# - **Pensamento Crítico**: Análise de problemas de forma lógica e objetiva, buscando soluções eficientes.
# - **Gestão de Tempo**: Capacidade de organizar e priorizar tarefas, garantindo entregas dentro dos prazos estipulados.
#
# ---
#
# # 4. Breve Descrição sobre minhas Skills
#
# Sou um **analista de dados** apaixonado por resolver problemas complexos utilizando dados. Tenho uma sólida **formação acadêmica** e **experiência prática** com ferramentas de análise e visualização de dados, como **Python** e **Power BI**. Além disso, sou constantemente **proativo em aprender novas ferramentas** e técnicas para melhorar o meu trabalho, e busco sempre transformar **dados em informações valiosas** para a tomada de decisões.
#
# Combinando **hard skills** como programação e análise quantitativa com **soft skills** como comunicação e gestão de tempo, estou preparado para enfrentar desafios e colaborar com equipes para alcançar resultados significativos.

# %% [markdown]
# ## 5. Introdução Python

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Salerno")
# Out:
# Salerno

# %%
print(2 + 2)
# Out:
# 4

# %%
print("Priscilla")
# Out:
# Priscilla

# %%
print(10 / 5)
# Out:
# 2.0

# %% [markdown]
# # 6. **Estatística**

# %% [markdown]
# * * *
#
# # 7. Hobbies e Interesses
#
# Além da minha paixão por dados, tenho alguns hobbies que me ajudam a relaxar e a ver o mundo por outras perspectivas:
#
# *   **Música**: 🎶 Gosto de ouvir diversos gêneros e explorar novos artistas.
# *   **Leitura**: 📚 Livros sobre tecnologia, ficção científica e desenvolvimento pessoal são meus favoritos.
# *   **Caminhada/Corrida**: 🏃‍♂️ Manter-me ativo é importante para minha saúde e bem-estar.
# *   **Fotografia**: 📸 Capturar momentos e paisagens me permite expressar criatividade.
# *   **Cozinhar**: 🍳 Experimentar novas receitas e sabores é um prazer.

# %%
import pandas as pd

# Create a dictionary with some data
data = {'coluna_A': [1, 2, 3, 5],
        'coluna_B': ['A', 'B', 'C', 'D']}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Display the DataFrame
display(df)
# Out:
#    coluna_A coluna_B
# 0         1        A
# 1         2        B
# 2         3        C
# 3         5        D

# %%
import pandas as pd

# Create another dictionary with some data
data_2 = {'Nome': ['João', 'Maria', 'Pedro'],
          'Idade': [25, 30, 22],
          'Cidade': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte']}

# Create a DataFrame from the dictionary
df_2 = pd.DataFrame(data_2)

# Display the DataFrame
display(df_2)
# Out:
#     Nome  Idade          Cidade
# 0   João     25       São Paulo
# 1  Maria     30  Rio de Janeiro
# 2  Pedro     22  Belo Horizonte

# %%
# @title Nome vs Cidade

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Cidade'].value_counts()
    for x_label, grp in df_2.groupby('Nome')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Nome')
_ = plt.ylabel('Cidade')

# %%
plt.savefig('nome_vs_cidade.png')

# %% [markdown]
# # 8. Estratégia
#
# - Data warehouses
# - disseminação do grande volume de dados usando conceitos e Big Data
# - Nudge: empurraozinhooooooo
# - kjlbsfklbfsdjklfbsjklb
# - fjkbdsjkcbdjc

# %% [markdown]
# # 9. Estatística
#
# Aqui vamos calcular a média

# %%
a = [1, 2, 3]

media = sum(a) / len(a)

print(media)
# Out:
# 2.0

# %% [markdown]
# texto

# %% [markdown]
# <div style="text-align: center;">
#   <strong style="font-size: 24px; rgba(20, 114, 6, 1);">Curso: Análise de Dados para a Tomada de Decisão</strong>
# </div>

# %% [markdown]
# # Task
# Gere um arquivo de texto armazenado no drive e use o pandas para importa-lo.

# %% [markdown]
# ## Montar o google drive
#
# ### Subtask:
# Conectar o Google Drive ao Colab para poder acessar os arquivos.

# %% [markdown]
# **Reasoning**:
# Import the google.colab library and mount Google Drive to access files.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Criar e salvar o arquivo de texto
#
# ### Subtask:
# Gerar um conteúdo de exemplo e salvá-lo como um arquivo de texto no Google Drive.

# %% [markdown]
# **Reasoning**:
# Create example data and save it to a text file in Google Drive.

# %%
# Create example data
example_data = """coluna1,coluna2,coluna3
valor1_1,valor1_2,valor1_3
valor2_1,valor2_2,valor2_3
valor3_1,valor3_2,valor3_3
"""

# Define the file path in Google Drive
file_path = '/content/drive/MyDrive/exemplo_dados.txt'

# Open the file in write mode and write the data
with open(file_path, 'w') as f:
  f.write(example_data)

print(f"File saved successfully to {file_path}")
# Out:
# File saved successfully to /content/drive/MyDrive/exemplo_dados.txt

# %% [markdown]
# ## Importar o arquivo com pandas
#
# ### Subtask:
# Usar a biblioteca pandas para ler o conteúdo do arquivo de texto salvo no Google Drive.

# %% [markdown]
# **Reasoning**:
# Use pandas to read the text file from Google Drive and store it in a DataFrame.

# %%
import pandas as pd

# Define the file path of the text file saved in Google Drive
file_path = '/content/drive/MyDrive/exemplo_dados.txt'

# Use the pd.read_csv() function to read the text file into a pandas DataFrame
# Assuming the file is comma-separated as created in the previous step
df_imported = pd.read_csv(file_path)

# Display the imported DataFrame
display(df_imported)
# Out:
#     coluna1   coluna2   coluna3
# 0  valor1_1  valor1_2  valor1_3
# 1  valor2_1  valor2_2  valor2_3
# 2  valor3_1  valor3_2  valor3_3

# %% [markdown]
# ## Exibir o conteúdo importado
#
# ### Subtask:
# Mostrar o DataFrame criado a partir do arquivo de texto para verificar se a importação foi bem-sucedida.

# %% [markdown]
# **Reasoning**:
# Display the imported DataFrame to verify its content.

# %%
display(df_imported)
# Out:
#     coluna1   coluna2   coluna3
# 0  valor1_1  valor1_2  valor1_3
# 1  valor2_1  valor2_2  valor2_3
# 2  valor3_1  valor3_2  valor3_3

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   A conexão com o Google Drive foi estabelecida com sucesso no ambiente do Colab.
# *   Um arquivo de texto (`exemplo_dados.txt`) contendo dados de exemplo formatados como CSV foi criado e salvo no diretório `MyDrive` do Google Drive.
# *   O arquivo `exemplo_dados.txt` foi lido com sucesso para um DataFrame pandas (`df_imported`) usando a função `pd.read_csv()`.
# *   O conteúdo do DataFrame importado correspondeu aos dados originais criados no arquivo de texto, confirmando a importação bem-sucedida.
#
# ### Insights or Next Steps
#
# *   O DataFrame importado (`df_imported`) está pronto para ser utilizado em análises de dados subsequentes com pandas.
# *   Este processo pode ser adaptado para importar qualquer arquivo de texto formatado (como CSV, TSV, etc.) armazenado no Google Drive para análise no Colab.

# %%
import requests
import json

# Definindo o endpoint da API
url = "https://olinda.bcb.gov.br/olinda/servico/SaldosContabeisMensais/v1/odata/SaldosContabeisMensais"

# Definindo os parâmetros da requisição (exemplo de filtro por mês)
params = {
    "$filter": "Mes eq '2025-08'",  # exemplo de filtro para agosto de 2025
    "$top": 10  # limitar os resultados
}

# Fazendo a requisição GET
response = requests.get(url, params=params)

# Verificando se a requisição foi bem-sucedida (status code 200)
if response.status_code == 200:
    # Convertendo a resposta JSON para um dicionário Python
    data = response.json()

    # Imprimindo os dados
    print(json.dumps(data, indent=4))
else:
    print(f"Erro na requisição: {response.status_code}")
# Out:
# Erro na requisição: 403

# %%
import requests
import json

# Definindo o endpoint da API
url = "https://olinda.bcb.gov.br/olinda/servico/SaldosContabeisMensais/v1/odata/SaldosContabeisMensais"

# Definindo os parâmetros da requisição
params = {
    "$filter": "Mes eq '2025-08'",  # exemplo de filtro para agosto de 2025
    "$top": 10  # limitar os resultados
}

# Definindo os cabeçalhos
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# Fazendo a requisição GET
response = requests.get(url, params=params, headers=headers)

# Verificando se a requisição foi bem-sucedida
if response.status_code == 200:
    # Convertendo a resposta JSON para um dicionário Python
    data = response.json()
    # Imprimindo os dados
    print(json.dumps(data, indent=4))
else:
    print(f"Erro na requisição: {response.status_code}")
# Out:
# Erro na requisição: 403

# %% [markdown]
# # 10. Pandas

# %%
import pandas as pd

df = pd.read_csv("/content/titanic.txt", sep=",")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_nome_pass = df['Name']
print(titanic_nome_pass)
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                  Heikkinen, Miss Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                          Graham, Miss Margaret Edith
# 888              Johnston, Miss Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic_duas_colunas = df[['Name', 'Age']]
print(titanic_duas_colunas)
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                                Heikkinen, Miss Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                        Graham, Miss Margaret Edith  19.0
# 888            Johnston, Miss Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
len(df)
# Out:
# 891

# %%
len(df.columns)
# Out:
# 12

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
smallTitanic = df.head(10)[["Name", "Age"]]

print(smallTitanic)
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                              Heikkinen, Miss Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0
# 5                                   Moran, Mr. James   NaN
# 6                            McCarthy, Mr. Timothy J  54.0
# 7                      Palsson, Master Gosta Leonard   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0

# %%
smallTitanicFiltered = df[df["Age"] > 30]

print(smallTitanicFiltered)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                             Bonnell, Miss Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
drescricao = df.describe()

print(drescricao)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.iloc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
df.iloc[1:10, 0:2]
# Out:
#    PassengerId  Survived
# 1            2         1
# 2            3         1
# 3            4         1
# 4            5         0
# 5            6         0
# 6            7         0
# 7            8         0
# 8            9         1
# 9           10         1

# %%
df = df.rename(columns={'Age': 'Idade', 'Name': 'Nome'})
display(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Nome     Sex  Idade  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                              Heikkinen, Miss Laina  female   26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0      1
# 4                           Allen, Mr. William Henry    male   35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Nome     Sex  Idade  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
dados1 = {
    'Produto': ['Camiseta', 'Calça', 'Jaqueta', 'Tênis'],
    'Preço': [50, 100, 150, None],
    'Quantidade': [100, 150, 300, None]
}

# %%
print(dados1)
# Out:
# {'Produto': ['Camiseta', 'Calça', 'Jaqueta', 'Tênis'], 'Preço': [50, 100, 150, None], 'Quantidade': [100, 150, 300, None]}

# %%
df1 = pd.DataFrame(dados1)

# Exibindo o DataFrame
print(df1)

print()
# Out:
#     Produto  Preço  Quantidade
# 0  Camiseta   50.0       100.0
# 1     Calça  100.0       150.0
# 2   Jaqueta  150.0       300.0
# 3     Tênis    NaN         NaN

# %%
# Substituir valores ausentes por quinhentos
df1.fillna(500, inplace=True)

print(df1)
# Out:
#     Produto  Preço  Quantidade
# 0  Camiseta   50.0       100.0
# 1     Calça  100.0       150.0
# 2   Jaqueta  150.0       300.0
# 3     Tênis  500.0       500.0

# %%
# agrupamento horizontal
import pandas as pd

# DataFrame 1: Produtos
produtos = {
    'Produto': ['Camiseta', 'Calça', 'Jaqueta', 'Tênis'],
    'Preço': [50, 100, 200, 150]
}

df_produtos = pd.DataFrame(produtos)

# DataFrame 2: Vendas
vendas = {
    'Quantidade': [100, 150, 80, 120]
}

grade = {
    'Notas': ["A", "B", "C", "D"]
}

df_vendas = pd.DataFrame(vendas)

df_grade = pd.DataFrame(grade)

df_vendas = pd.DataFrame(vendas)

# Agrupar horizontalmente (adicionar as colunas de df_vendas ao df_produtos)
df_completo = pd.concat([df_produtos, df_vendas, df_grade], axis=1)

# Calcular o Preço Total
df_completo['Preço Total'] = df_completo['Preço'] * df_completo['Quantidade']

# Exibir o DataFrame resultante
print(df_completo)
# Out:
#     Produto  Preço  Quantidade Notas  Preço Total
# 0  Camiseta     50         100     A         5000
# 1     Calça    100         150     B        15000
# 2   Jaqueta    200          80     C        16000
# 3     Tênis    150         120     D        18000

# %% [markdown]
# # 12. Estatística

# %% [markdown]
# #### Cálculo da Média
# <hr style="border: 1px solid rgba(242, 248, 241, 1); width: 100%; margin: 5px 0;">
#
#
# A fórmula da **média** é usada para calcular o valor médio de um conjunto de dados. A fórmula é dada por:
#
# $$
# \text{Média} = \frac{\sum_{i=1}^{n} x_i}{n}
# $$
#
# Onde:
# - $( x_i )$ representa cada valor do conjunto de dados.
# - $( n )$ é o número total de elementos.
#
# ### Exemplo:
#
# Se tivermos os seguintes números: **2, 4, 6, 8, 10**, a média será:
#
# $$
# \text{Média} = \frac{2 + 4 + 6 + 8 + 10}{5} = \frac{30}{5} = 6
# $$

# %%
# Média

a = [2, 4, 6, 8, 10]

print(f'Média: {sum(a) / len(a)}')
# Out:
# Média: 6.0

# %%
import statistics as st

print(f'Média: {st.mean(a)}')
# Out:
# Média: 6

# %%
# número ímpar de elementos
b = [1500, 1800, 2000, 2100, 2200, 2400]

print(f'Mediana: {sorted(b)[len(b) // 2] if len(b) % 2 != 0 else (sorted(b)[len(b) // 2 - 1] + sorted(b)[len(b) // 2]) / 2}')
# Out:
# Mediana: 2050.0

# %%
10 % 3
# Out:
# 1

# %%
import numpy as np
import pandas as pd
from statistics import mode

notas = [8, 7, 6, 7, 7, 8, 10, 9, 6, 7, 8, 2, 10, 9, 7, 6, 8, 9, 5, 10]

media = np.mean(notas)
mediana = np.median(notas)
moda = mode(notas)

print("Média   :", media)
print("Mediana :", mediana)
print("Moda    :", moda)
# Out:
# Média   : 7.45
# Mediana : 7.5
# Moda    : 7

# %%
amplitude = max(notas) - min(notas)
variancia = np.var(notas, ddof=1)   # ddof=1 → amostral
desvio_padrao = np.std(notas, ddof=1)
cv = desvio_padrao / media

print("Amplitude        :", amplitude)
print("Variância        :", variancia)
print("Desvio Padrão    :", desvio_padrao)
print("Coef. Variação   :", cv)
# Out:
# Amplitude        : 8
# Variância        : 3.7342105263157896
# Desvio Padrão    : 1.9324105480761042
# Coef. Variação   : 0.259383966184712

# %% [markdown]
# # 13. Visualização

# %%
notas = [8, 7, 6, 9, 7, 8, 10, 9, 6, 7, 8, 2, 10, 9, 7, 6, 8, 9, 5, 10]

# %%
import matplotlib.pyplot as plt

plt.hist(notas, bins=10, edgecolor="green")
plt.title("Histograma de Notas")
plt.xlabel("Notas")
plt.ylabel("Quant")

# Salva a imagem (antes do show)
#plt.savefig("../img/histograma_notas.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
import pandas as pd

df = pd.DataFrame({"Notas": notas})
contagem = df["Notas"].value_counts().sort_index()

contagem.plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("Frequência das Notas")
plt.xlabel("Nota")
plt.ylabel("Quantidade")

# Salva a imagem (antes do show)
#plt.savefig("../img/barras_notas.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
contagem.plot(kind="pie", autopct="%1.1f%%", figsize=(6,6))
plt.title("Proporção de cada Nota")
plt.ylabel("")  # remove label lateral

#plt.savefig("../img/pizza_notas.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(notas, marker="o")
plt.title("Notas na ordem de resposta")
plt.xlabel("Aluno")
plt.ylabel("Nota")

# Define ticks do eixo X como inteiros (1 até número de alunos)
plt.xticks(range(len(notas)), range(1, len(notas)+1))

#plt.savefig("../img/linha_notas.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.linspace(0, 2 * np.pi, 1024)
data2d = np.sin(t)[:, np.newaxis] * np.cos(t)[np.newaxis, :]

fig, ax = plt.subplots()
im = ax.imshow(data2d)
ax.set_title('Pan on the colorbar to shift the color mapping\n'
             'Zoom on the colorbar to scale the color mapping')

fig.colorbar(im, ax=ax, label='Interactive colorbar')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1, len(notas)+1)  # alunos (1 a 20)
y = np.array(notas)

# Ajuste de uma reta (1º grau)
coef = np.polyfit(x, y, 1)   # coef[0] = inclinação, coef[1] = intercepto
tendencia = np.poly1d(coef)

plt.plot(x, y, marker="o", label="Notas")
plt.plot(x, tendencia(x), color="red", linestyle="--", label="Tendência")

plt.title("Notas na ordem de resposta com linha de tendência")
plt.xlabel("Aluno")
plt.ylabel("Nota")

plt.xticks(range(len(notas)), range(1, len(notas)+1))
plt.legend()

#plt.savefig("../img/linhat_notas.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import numpy as np
import pandas as pd

rng = np.random.default_rng(42)

# Parâmetros
n_customers = 1500
start = pd.Timestamp("2023-01-01")
end   = pd.Timestamp("2025-07-31")
dates = pd.date_range(start, end, freq="D")

# Tabela de clientes
plans = ["Basic", "Pro", "Enterprise"]
regions = ["Sudeste", "Sul", "Nordeste", "Centro-Oeste", "Norte"]

customers = pd.DataFrame({
    "customer_id": np.arange(1, n_customers+1),
    "signup_date": rng.choice(pd.date_range("2023-01-01","2025-06-01", freq="D"), size=n_customers),
    "plan": rng.choice(plans, p=[0.55, 0.35, 0.10], size=n_customers),
    "region": rng.choice(regions, size=n_customers, p=[0.45,0.20,0.18,0.10,0.07])
})

# Probabilidade de churn depende do plano (mais alta no Basic)
base_churn = customers["plan"].map({"Basic":0.22,"Pro":0.12,"Enterprise":0.06}).values
churned = rng.random(n_customers) < base_churn
customers["churned"] = churned
# churn_date após signup para quem churnou
churn_dates = customers["signup_date"] + pd.to_timedelta(rng.integers(30, 540, size=n_customers), unit="D")
customers["churn_date"] = np.where(churned, churn_dates, pd.NaT)
customers["churn_date"] = pd.to_datetime(customers["churn_date"])

# Catálogo simples
products = pd.DataFrame({
    "product": ["Widget A","Widget B","Gadget X","Gadget Y","Service Plus","Service Care","Add-on 1","Add-on 2"],
    "category": ["Hardware","Hardware","Hardware","Hardware","Serviço","Serviço","Add-on","Add-on"],
    "base_price": [120, 200, 340, 280, 150, 80, 40, 60]
})

# Geração de pedidos (vendas)
orders_list = []
for d in dates:
    # sazonalidade simples: mais vendas em fim de mês e em nov-dez
    month = d.month
    dow = d.dayofweek
    mult = 1.0 + 0.25*(month in [11,12]) + 0.15*(d.day>25) + 0.10*(dow in [4,5])  # 6=sábado, 0=segunda
    n_orders = rng.poisson(80*mult)

    cust_today = rng.choice(customers["customer_id"].values, size=n_orders, replace=True)
    prod_today = rng.choice(products["product"].values, size=n_orders, replace=True)

    df_day = pd.DataFrame({"order_date": d, "customer_id": cust_today, "product": prod_today})
    df_day = df_day.merge(products, on="product", how="left")
    # quantidade e preço com leve variação
    df_day["qty"] = rng.integers(1, 5, size=n_orders)
    df_day["unit_price"] = (df_day["base_price"] * rng.normal(1.0, 0.08, size=n_orders)).round(2)
    df_day["revenue"] = (df_day["qty"] * df_day["unit_price"]).round(2)
    orders_list.append(df_day)

orders = pd.concat(orders_list, ignore_index=True)

# Junta metadados do cliente (plan, region) no pedido
orders = orders.merge(customers[["customer_id","plan","region","signup_date","churned","churn_date"]],
                      on="customer_id", how="left")

# Filtra pedidos após signup e antes do churn (se houver)
orders = orders[(orders["order_date"] >= orders["signup_date"]) &
                (orders["churn_date"].isna() | (orders["order_date"] <= orders["churn_date"]))].reset_index(drop=True)

orders.head(), customers.head()
# Out:
# (  order_date  customer_id       product  category  base_price  qty  \
#  0 2023-01-04         1409      Gadget X  Hardware         340    4
#  1 2023-01-06          381      Widget B  Hardware         200    2
#  2 2023-01-09          845  Service Care   Serviço          80    3
#  3 2023-01-09          465      Add-on 1    Add-on          40    4
#  4 2023-01-10         1175  Service Care   Serviço          80    2
#
#     unit_price  revenue        plan        region signup_date  churned  \
#  0      350.23  1400.92       Basic  Centro-Oeste  2023-01-02    False
#  1      203.15   406.30  Enterprise       Sudeste  2023-01-05    False
#  2       79.10   237.30         Pro           Sul  2023-01-05    False
#  3       39.34   157.36       Basic  Centro-Oeste  2023-01-06    False
#  4       90.56   181.12       Basic       Sudeste  2023-01-08    False
#
#    churn_date
#  0        NaT
#  1        NaT
#  2        NaT
#  3        NaT
#  4        NaT  ,
# ...

# %%
import matplotlib.pyplot as plt

rev_daily = orders.groupby("order_date")["revenue"].sum().rename("revenue")
rev_7dma = rev_daily.rolling(7).mean()

plt.figure(figsize=(10,4))
plt.plot(rev_daily.index, rev_daily.values, label="Receita diária")
plt.plot(rev_7dma.index, rev_7dma.values, label="Média móvel 7d")
plt.title("Receita ao longo do tempo")
plt.xlabel("Data"); plt.ylabel("Receita")
plt.legend(); plt.tight_layout(); plt.show()
